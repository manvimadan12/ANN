# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
#onehotencoder = OneHotEncoder(categorical_features = [1])
#X = onehotencoder.fit_transform(X).toarray()
#X = X[:, 1:]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Country column
ct = ColumnTransformer([("Country", OneHotEncoder(), [1])], remainder = 'passthrough')
X = ct.fit_transform(X)

# Male/Female
#labelencoder_X = LabelEncoder()
#X[:, 2] = labelencoder_X.fit_transform(X[:, 2])

# %%
#aavoiding dummy value trap
X = X[:, 1:]

# %%
X
# Out:
# array([[0.0, 0.0, 619, ..., 1, 1, 101348.88],
#        [0.0, 1.0, 608, ..., 0, 1, 112542.58],
#        [0.0, 0.0, 502, ..., 1, 0, 113931.57],
#        ...,
#        [0.0, 0.0, 709, ..., 0, 1, 42085.58],
#        [1.0, 0.0, 772, ..., 1, 0, 92888.52],
#        [0.0, 0.0, 792, ..., 1, 0, 38190.78]], dtype=object)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# %%
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.4000 - accuracy: 0.8361
# Epoch 2/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3996 - accuracy: 0.8350
# Epoch 3/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3992 - accuracy: 0.8378
# Epoch 4/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3995 - accuracy: 0.8361
# Epoch 5/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 6/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3990 - accuracy: 0.8345
# Epoch 7/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3999 - accuracy: 0.8355
# Epoch 8/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3995 - accuracy: 0.8367
# Epoch 9/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3991 - accuracy: 0.8361
# Epoch 10/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3997 - accuracy: 0.8371
# Epoch 11/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3993 - accuracy: 0.8388
# Epoch 12/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.4000 - accuracy: 0.8356
# Epoch 13/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 14/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3996 - accuracy: 0.8359
# Epoch 15/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8355
# Epoch 16/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3993 - accuracy: 0.8365
# Epoch 17/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 18/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 19/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8369
# Epoch 20/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3999 - accuracy: 0.8360
# Epoch 21/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3992 - accuracy: 0.8371
# Epoch 22/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8369
# Epoch 23/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8345
# Epoch 24/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3996 - accuracy: 0.8371
# Epoch 25/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3996 - accuracy: 0.8376
# Epoch 26/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 27/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3994 - accuracy: 0.8370
# Epoch 28/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3993 - accuracy: 0.8378
# Epoch 29/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3997 - accuracy: 0.8349
# Epoch 30/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3996 - accuracy: 0.8351
# Epoch 31/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3994 - accuracy: 0.8364
# Epoch 32/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3993 - accuracy: 0.8366
# Epoch 33/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3995 - accuracy: 0.8382
# Epoch 34/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3996 - accuracy: 0.8363
# Epoch 35/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8364
# Epoch 36/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3995 - accuracy: 0.8375
# Epoch 37/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3995 - accuracy: 0.8349
# Epoch 38/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 39/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8372
# Epoch 40/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3992 - accuracy: 0.8354
# Epoch 41/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8376
# Epoch 42/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8340
# Epoch 43/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8365
# Epoch 44/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8361
# Epoch 45/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8361
# Epoch 46/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3997 - accuracy: 0.8340
# Epoch 47/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3990 - accuracy: 0.8370
# Epoch 48/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3996 - accuracy: 0.8365
# Epoch 49/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3986 - accuracy: 0.8363
# Epoch 50/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 51/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8349
# Epoch 52/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 53/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3991 - accuracy: 0.8350
# Epoch 54/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8351
# Epoch 55/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3996 - accuracy: 0.8366
# Epoch 56/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3993 - accuracy: 0.8353
# Epoch 57/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3992 - accuracy: 0.8370
# Epoch 58/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8374
# Epoch 59/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 60/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3990 - accuracy: 0.8369
# Epoch 61/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3990 - accuracy: 0.8338
# Epoch 62/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3994 - accuracy: 0.8363
# Epoch 63/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3995 - accuracy: 0.8355
# Epoch 64/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8370
# Epoch 65/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 66/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3989 - accuracy: 0.8359
# Epoch 67/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8353
# Epoch 68/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3995 - accuracy: 0.8351
# Epoch 69/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8361
# Epoch 70/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3990 - accuracy: 0.8346
# Epoch 71/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8378
# Epoch 72/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3993 - accuracy: 0.8365
# Epoch 73/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3993 - accuracy: 0.8367
# Epoch 74/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 75/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8365
# Epoch 76/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3992 - accuracy: 0.8379
# Epoch 77/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8350
# Epoch 78/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3990 - accuracy: 0.8346
# Epoch 79/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8359
# Epoch 80/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3991 - accuracy: 0.8350
# Epoch 81/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3991 - accuracy: 0.8354
# Epoch 82/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 83/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 84/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3990 - accuracy: 0.8357
# Epoch 85/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8359
# Epoch 86/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3988 - accuracy: 0.8354
# Epoch 87/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3993 - accuracy: 0.8357
# Epoch 88/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3991 - accuracy: 0.8366
# Epoch 89/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 90/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 91/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3988 - accuracy: 0.8359
# Epoch 92/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 93/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8355
# Epoch 94/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 95/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3992 - accuracy: 0.8355
# Epoch 96/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3991 - accuracy: 0.8360
# Epoch 97/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3985 - accuracy: 0.8371
# Epoch 98/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3991 - accuracy: 0.8355
# Epoch 99/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3992 - accuracy: 0.8359
# Epoch 100/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3990 - accuracy: 0.8349

# %%
classifier.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 6)                 72
# _________________________________________________________________
# dense_29 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1536,   59],
#        [ 253,  152]])
